# %% [markdown]
# # Relatório de Analises VII

# %% [markdown]
# ## Criando agrupamentos

# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/aluguel_residencial.csv', sep = ';')

# %%
dados.head(10)
# Out:
#                  Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 0           Quitinete           Copacabana        1      0       0    40
# 1                Casa      Jardim Botânico        2      0       1   100
# 2         Apartamento               Centro        1      0       0    15
# 3         Apartamento         Higienópolis        1      0       0    48
# 4         Apartamento             Cachambi        2      0       0    50
# 5  Casa de Condomínio      Barra da Tijuca        5      4       5   750
# 6  Casa de Condomínio                Ramos        2      2       0    65
# 7         Apartamento               Grajaú        2      1       0    70
# 8         Apartamento  Lins de Vasconcelos        3      1       1    90
# 9         Apartamento           Copacabana        1      0       1    40
#
#      Valor  Condominio  IPTU
# 0   1700.0       500.0  60.0
# 1   7000.0         0.0   0.0
# 2    800.0       390.0  20.0
# 3    800.0       230.0   0.0
# ...

# %%
dados.Valor.mean()
# Out:
# 5046.172821405663

# %%
list(dados.Bairro.unique())
# Out:
# ['Copacabana',
#  'Jardim Botânico',
#  'Centro',
#  'Higienópolis',
#  'Cachambi',
#  'Barra da Tijuca',
#  'Ramos',
#  'Grajaú',
#  'Lins de Vasconcelos',
#  'Taquara',
#  'Freguesia (Jacarepaguá)',
#  'Tijuca',
#  'Olaria',
#  'Ipanema',
#  'Campo Grande',
#  'Botafogo',
#  'Recreio dos Bandeirantes',
#  'Leblon',
#  'Jardim Oceânico',
#  'Humaitá',
#  'Península',
#  'Méier',
#  'Vargem Pequena',
#  'Maracanã',
#  'Jacarepaguá',
#  'São Conrado',
#  'Vila Valqueire',
#  'Gávea',
#  'Cosme Velho',
#  'Bonsucesso',
#  'Todos os Santos',
#  'Laranjeiras',
#  'Itanhangá',
#  'Flamengo',
#  'Piedade',
#  'Lagoa',
#  'Catete',
#  'Jardim Carioca',
#  'Benfica',
#  'Glória',
#  'Praça Seca',
#  'Vila Isabel',
#  'Engenho Novo',
#  'Engenho de Dentro',
#  'Pilares',
#  'Água Santa',
#  'São Cristóvão',
#  'Ilha do Governador',
#  'Jardim Sulacap',
#  'Oswaldo Cruz',
#  'Vila da Penha',
#  'Anil',
#  'Vargem Grande',
#  'Tanque',
#  'Vaz Lobo',
#  'Madureira',
#  'São Francisco Xavier',
# ...

# %%
bairros = list(dados.Bairro.unique())
bairros
# Out:
# ['Copacabana',
#  'Jardim Botânico',
#  'Centro',
#  'Higienópolis',
#  'Cachambi',
#  'Barra da Tijuca',
#  'Ramos',
#  'Grajaú',
#  'Lins de Vasconcelos',
#  'Taquara',
#  'Freguesia (Jacarepaguá)',
#  'Tijuca',
#  'Olaria',
#  'Ipanema',
#  'Campo Grande',
#  'Botafogo',
#  'Recreio dos Bandeirantes',
#  'Leblon',
#  'Jardim Oceânico',
#  'Humaitá',
#  'Península',
#  'Méier',
#  'Vargem Pequena',
#  'Maracanã',
#  'Jacarepaguá',
#  'São Conrado',
#  'Vila Valqueire',
#  'Gávea',
#  'Cosme Velho',
#  'Bonsucesso',
#  'Todos os Santos',
#  'Laranjeiras',
#  'Itanhangá',
#  'Flamengo',
#  'Piedade',
#  'Lagoa',
#  'Catete',
#  'Jardim Carioca',
#  'Benfica',
#  'Glória',
#  'Praça Seca',
#  'Vila Isabel',
#  'Engenho Novo',
#  'Engenho de Dentro',
#  'Pilares',
#  'Água Santa',
#  'São Cristóvão',
#  'Ilha do Governador',
#  'Jardim Sulacap',
#  'Oswaldo Cruz',
#  'Vila da Penha',
#  'Anil',
#  'Vargem Grande',
#  'Tanque',
#  'Vaz Lobo',
#  'Madureira',
#  'São Francisco Xavier',
# ...

# %%
grupo_bairro = dados.groupby('Bairro')

# %%
grupo_bairro.head(10)
# Out:
#               Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0        Quitinete       Copacabana        1      0       0    40  1700.0
# 1             Casa  Jardim Botânico        2      0       1   100  7000.0
# 2      Apartamento           Centro        1      0       0    15   800.0
# 3      Apartamento     Higienópolis        1      0       0    48   800.0
# 4      Apartamento         Cachambi        2      0       0    50  1300.0
# ...            ...              ...      ...    ...     ...   ...     ...
# 21421  Apartamento          Sampaio        1      0       0    36   650.0
# 21454         Casa          Turiaçu        2      1       0    45   700.0
# 21564  Apartamento      Cidade Nova        2      1       0    57  1600.0
# 21733  Apartamento  Parada de Lucas        2      1       0    55   900.0
# 21734  Apartamento          Sampaio        3      0       0    97  1300.0
#
#        Condominio  IPTU
# 0           500.0  60.0
# 1             0.0   0.0
# ...

# %%
len(grupo_bairro.groups.keys())
# Out:
# 152

# %%
for b,d in grupo_bairro:
    print("{} -> {}".format(b,d.Valor.mean()))
# Out:
# Abolição -> 1195.3333333333333
# Alto da Boa Vista -> 3966.6666666666665
# Anchieta -> 875.0
# Andaraí -> 1464.7113402061855
# Anil -> 2048.8732394366198
# Arpoador -> 12923.916666666666
# Bancários -> 1825.0
# Bangu -> 1016.0
# Barra da Tijuca -> 7069.552938130986
# Barra de Guaratiba -> 5550.0
# Benfica -> 996.0
# Bento Ribeiro -> 1030.8695652173913
# Bonsucesso -> 1225.9322033898304
# Botafogo -> 8791.828178694159
# Braz de Pina -> 1115.0
# Cachambi -> 1157.1742424242425
# Cachamorra -> 3000.0
# Cacuia -> 916.6666666666666
# Caju -> 850.0
# Camorim -> 1735.2272727272727
# Campinho -> 1037.3333333333333
# Campo Grande -> 1267.71714922049
# Cascadura -> 948.7096774193549
# Catete -> 2267.0625
# Catumbi -> 1112.5
# Cavalcanti -> 595.0
# Centro -> 1254.7521865889212
# Cidade Jardim -> 12000.0
# Cidade Nova -> 1471.4285714285713
# Cocotá -> 1883.3333333333333
# Coelho Neto -> 700.0
# Colégio -> 885.0
# Copacabana -> 4126.677004538578
# Cordovil -> 905.5555555555555
# ...

# %%
# outra forma
grupo_bairro[['Valor', 'Condominio']].mean().round(2)
# Out:
#                      Valor  Condominio
# Bairro
# Abolição           1195.33      191.40
# Alto da Boa Vista  3966.67      885.00
# Anchieta            875.00       19.75
# Andaraí            1464.71      497.71
# Anil               2048.87      455.85
# ...                    ...         ...
# Vila Valqueire     1769.58      276.88
# Vila da Penha      1260.58      232.68
# Vista Alegre       1114.38      210.06
# Zumbi              2150.00     1050.00
# Água Santa          861.11      269.44
#
# [152 rows x 2 columns]

# %% [markdown]
# ## Estatística descritiva

# %%
grupo_bairro.Valor.describe().round(2)
# Out:
#                    count     mean      std     min     25%     50%     75%  \
# Bairro
# Abolição            15.0  1195.33   425.32   800.0   900.0  1180.0  1200.0
# Alto da Boa Vista    6.0  3966.67  5513.59   600.0  1150.0  1725.0  3275.0
# Anchieta             4.0   875.00   132.29   700.0   812.5   900.0   962.5
# Andaraí             97.0  1464.71   408.11   700.0  1200.0  1400.0  1650.0
# Anil                71.0  2048.87  1523.97   300.0  1100.0  1500.0  2675.0
# ...                  ...      ...      ...     ...     ...     ...     ...
# Vila Valqueire      48.0  1769.58  2203.01   800.0  1000.0  1250.0  1700.0
# Vila da Penha      104.0  1260.58   644.66   450.0   900.0  1100.0  1302.5
# Vista Alegre        16.0  1114.38   199.60   700.0  1012.5  1200.0  1225.0
# Zumbi                2.0  2150.00   777.82  1600.0  1875.0  2150.0  2425.0
# Água Santa           9.0   861.11   174.60   600.0   800.0   850.0   950.0
#
#                        max
# Bairro
# ...

# %%
grupo_bairro['Valor'].aggregate(['min', 'max', 'sum']).sort_values(by = 'min').rename(columns = {'min': 'Mínimo', 'max': 'Máximo','sum': 'Total'})
# Out:
#                     Mínimo    Máximo       Total
# Bairro
# Copacabana           100.0   35000.0  10910934.0
# Leblon               100.0  100000.0  11002902.0
# Anil                 300.0    7000.0    145470.0
# Engenho de Dentro    300.0    2000.0     86310.0
# Jacarepaguá          300.0   15000.0    501512.0
# ...                    ...       ...         ...
# Cachamorra          3000.0    3000.0      3000.0
# Jardim Oceânico     3500.0   17000.0    175400.0
# Arpoador            4200.0   30000.0    155087.0
# Joá                 6500.0   45000.0    385790.0
# Cidade Jardim      12000.0   12000.0     12000.0
#
# [152 rows x 3 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.rc('figure',figsize = (20,10))
fig = grupo_bairro.Valor.mean().plot.bar()
fig.set_ylabel = 'Valor do aluguel'
fig.set_title('Média do aluguel x Valor')
# Out:
# Text(0.5, 1.0, 'Média do aluguel x Valor')
